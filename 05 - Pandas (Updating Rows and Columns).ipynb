# %%
people = {
    "first": ["Corey", "Jane", "John"],
    "last": ["Schafer", "Doe", "Doe"],
    "email": ["Corey.Schafer@email.com", "JaneDoe@email.com", "JohnDoe@email.com"]
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  Corey.Schafer@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.columns = ['first_name', 'last_name', 'email']

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='object')

# %%
df
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  Corey.Schafer@email.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df
# Out:
#   FIRST_NAME LAST_NAME                    EMAIL
# 0      Corey   Schafer  Corey.Schafer@email.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.columns = df.columns.str.replace('_', ' ')

# %%
df
# Out:
#   FIRST NAME LAST NAME                    EMAIL
# 0      Corey   Schafer  Corey.Schafer@email.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df
# Out:
#   FIRST_NAME LAST_NAME                    EMAIL
# 0      Corey   Schafer  Corey.Schafer@email.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.columns = [x.lower() for x in df.columns]
df
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  Corey.Schafer@email.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.rename(columns = {'first_name': 'first', 'last_name': 'last'})
# Out:
#    first     last                    email
# 0  Corey  Schafer  Corey.Schafer@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  Corey.Schafer@email.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.rename(columns = {'first_name': 'first', 'last_name': 'last'}, inplace=True)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  Corey.Schafer@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.loc[2] = ['John', 'Smith', 'John.Smith@email.com']

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  Corey.Schafer@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith     John.Smith@email.com

# %%
df.loc[2, ['last','email']]
# Out:
# last                    Smith
# email    John.Smith@email.com
# Name: 2, dtype: object

# %%
df.loc[2, ['last','email']] = ['Doe', 'John.Doe@email.com']
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  Corey.Schafer@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe       John.Doe@email.com

# %%
df.loc[2, 'last'] = 'Smith'
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  Corey.Schafer@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith       John.Doe@email.com

# %%
df.at[2, 'last'] = 'Doe'
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  Corey.Schafer@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe       John.Doe@email.com

# %%
filt = (df['email'] == 'John.Doe@email.com')
df[filt]
# Out:
#   first last               email
# 2  John  Doe  John.Doe@email.com

# %%
df[filt]['last'] = 'Smith'
# Out:
# <ipython-input-26-f55762845eaa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[filt]['last'] = 'Smith'

# %%
df.loc[filt, 'last'] = 'Smith'
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  Corey.Schafer@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith       John.Doe@email.com

# %%
df['email'].str.lower()
# Out:
# 0    corey.schafer@email.com
# 1          janedoe@email.com
# 2         john.doe@email.com
# Name: email, dtype: object

# %%
df['email'] = df['email'].str.lower()
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  corey.schafer@email.com
# 1   Jane      Doe        janedoe@email.com
# 2   John    Smith       john.doe@email.com

# %% [markdown]
# ## apply, map, applymap,replace

# %% [markdown]
# ### apply

# %%
df['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    18
# Name: email, dtype: int64

# %%
def upper_email(email):
    return email.upper()

# %%
df['email'].apply(upper_email)
# Out:
# 0    COREY.SCHAFER@EMAIL.COM
# 1          JANEDOE@EMAIL.COM
# 2         JOHN.DOE@EMAIL.COM
# Name: email, dtype: object

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  corey.schafer@email.com
# 1   Jane      Doe        janedoe@email.com
# 2   John    Smith       john.doe@email.com

# %%
df['email'] = df['email'].apply(upper_email)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  COREY.SCHAFER@EMAIL.COM
# 1   Jane      Doe        JANEDOE@EMAIL.COM
# 2   John    Smith       JOHN.DOE@EMAIL.COM

# %%
df['email'] = df['email'].apply(lambda x: x.lower())
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  corey.schafer@email.com
# 1   Jane      Doe        janedoe@email.com
# 2   John    Smith       john.doe@email.com

# %%
df['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    18
# Name: email, dtype: int64

# %%
df.apply(len)
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
len(df['email'])
# Out:
# 3

# %%
df.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df.apply(pd.Series.min)
# Out:
# first                      Corey
# last                         Doe
# email    corey.schafer@email.com
# dtype: object

# %%
df.apply(lambda x: x.min())
# Out:
# first                      Corey
# last                         Doe
# email    corey.schafer@email.com
# dtype: object

# %% [markdown]
# ### applymap

# %%
df.applymap(len)
# Out:
#    first  last  email
# 0      5     7     23
# 1      4     3     17
# 2      4     5     18

# %%
df.applymap(str.lower)
# Out:
#    first     last                    email
# 0  corey  schafer  corey.schafer@email.com
# 1   jane      doe        janedoe@email.com
# 2   john    smith       john.doe@email.com

# %% [markdown]
# ### replace

# %%
df['first'].map({'Corey': 'Chris', 'Jane': 'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %%
df['first'].replace({'Corey': 'Chris', 'Jane': 'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2     John
# Name: first, dtype: object

# %%
df['first'] = df['first'].replace({'Corey': 'Chris', 'Jane': 'Mary'})
df
# Out:
#    first     last                    email
# 0  Chris  Schafer  corey.schafer@email.com
# 1   Mary      Doe        janedoe@email.com
# 2   John    Smith       john.doe@email.com

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)
df.head(1)
# Out:
#                                         MainBranch Hobbyist OpenSourcer  \
# Respondent
# 1           I am a student who is learning to code      Yes       Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
#
#                                         Employment         Country Student  \
# Respondent
# 1           Not employed, and not looking for work  United Kingdom      No
#
#                               EdLevel UndergradMajor  \
# Respondent
# 1           Primary/elementary school            NaN
#
#                                                      EduOther OrgSize DevType  \
# Respondent
# 1           Taught yourself a new language, framework, or ...     NaN     NaN
#
#            YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot  \
# Respondent
# 1                  4         10          NaN       NaN    NaN      NaN
#
# ...

# %%
df.loc[:, ['Hobbyist']].head(7)
# Out:
#            Hobbyist
# Respondent
# 1               Yes
# 2                No
# 3               Yes
# 4                No
# 5               Yes
# 6               Yes
# 7                No

# %%
df.loc[:, 'Hobbyist'].map({'Yes': True, 'No': False}).head(7)
# Out:
# Respondent
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6     True
# 7    False
# Name: Hobbyist, dtype: bool

# %%
df.loc[:, 'Hobbyist'] = df.loc[:, 'Hobbyist'].map({'Yes': True, 'No': False})
df.loc[:, 'Hobbyist']
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 22822     True
# 22823     True
# 22824     True
# 22825     True
# 22826     True
# Name: Hobbyist, Length: 22703, dtype: bool

# %%
df.loc[:, 'Hobbyist'] = df.loc[:, 'Hobbyist'].replace({'Yes': True, 'No': False})
df.loc[:, 'Hobbyist']
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 22822     True
# 22823     True
# 22824     True
# 22825     True
# 22826     True
# Name: Hobbyist, Length: 22703, dtype: bool
