# %%
people = {
    "first": ["Corey", "Jane", "John", "Adam"],
    "last": ["Schafer", "Doe", "Doe", "Smith"],
    "email": ["Corey.Schafer@email.com", "JaneDoe@email.com", "JohnDoe@email.com", "Adam.Smith@email.com"]
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  Corey.Schafer@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam    Smith     Adam.Smith@email.com

# %%
df.sort_values(by='last')
# Out:
#    first     last                    email
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 0  Corey  Schafer  Corey.Schafer@email.com
# 3   Adam    Smith     Adam.Smith@email.com

# %%
df.sort_values(by='last', ascending=False)
# Out:
#    first     last                    email
# 3   Adam    Smith     Adam.Smith@email.com
# 0  Corey  Schafer  Corey.Schafer@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.sort_values(by=['last', 'first'], ascending=False)
# Out:
#    first     last                    email
# 3   Adam    Smith     Adam.Smith@email.com
# 0  Corey  Schafer  Corey.Schafer@email.com
# 2   John      Doe        JohnDoe@email.com
# 1   Jane      Doe        JaneDoe@email.com

# %%
df.sort_values(by=['last', 'first'], ascending=[False, True])
# Out:
#    first     last                    email
# 3   Adam    Smith     Adam.Smith@email.com
# 0  Corey  Schafer  Corey.Schafer@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  Corey.Schafer@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam    Smith     Adam.Smith@email.com

# %%
df.sort_values(by=['last', 'first'], ascending=[False, True], inplace=True)
df
# Out:
#    first     last                    email
# 3   Adam    Smith     Adam.Smith@email.com
# 0  Corey  Schafer  Corey.Schafer@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.sort_index()
# Out:
#    first     last                    email
# 0  Corey  Schafer  Corey.Schafer@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam    Smith     Adam.Smith@email.com

# %%
df
# Out:
#    first     last                    email
# 3   Adam    Smith     Adam.Smith@email.com
# 0  Corey  Schafer  Corey.Schafer@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.sort_index(inplace=True)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  Corey.Schafer@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam    Smith     Adam.Smith@email.com

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col = 'Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col = 'Column')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.loc[:, ['Country']].head()
# Out:
#                            Country
# Respondent
# 1                   United Kingdom
# 2           Bosnia and Herzegovina
# 3                         Thailand
# 4                    United States
# 5                          Ukraine

# %%
df.sort_values(by='Country', inplace=True)
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 7085                           I am a developer by profession      Yes
# 722                            I am a developer by profession       No
# 12310       I used to be a developer by profession, but no...      Yes
# 10746                          I am a developer by profession      Yes
# 7353                           I am a developer by profession       No
#
#                                                   OpenSourcer  \
# Respondent
# 7085                                  Less than once per year
# 722         Less than once a month but more than once per ...
# 12310                              Once a month or more often
# 10746       Less than once a month but more than once per ...
# 7353                                                    Never
#
#                                                    OpenSource  \
# Respondent
# ...

# %%
df.loc[:, 'Country'].head(10)
# Out:
# Respondent
# 7085     Afghanistan
# 722      Afghanistan
# 12310    Afghanistan
# 10746    Afghanistan
# 7353     Afghanistan
# 6417     Afghanistan
# 8149     Afghanistan
# 22450    Afghanistan
# 3787         Albania
# 9270         Albania
# Name: Country, dtype: object

# %%
df.loc[:, ['Country', 'ConvertedComp']].head()
# Out:
#                 Country  ConvertedComp
# Respondent
# 7085        Afghanistan        14364.0
# 722         Afghanistan            0.0
# 12310       Afghanistan            NaN
# 10746       Afghanistan         3996.0
# 7353        Afghanistan            NaN

# %%
df.sort_values(by=['Country', 'ConvertedComp'], ascending=[True, False],inplace=True)

# %%
df.loc[:, ['Country', 'ConvertedComp']].head()
# Out:
#                 Country  ConvertedComp
# Respondent
# 7085        Afghanistan        14364.0
# 22450       Afghanistan         7980.0
# 10746       Afghanistan         3996.0
# 8149        Afghanistan         1596.0
# 722         Afghanistan            0.0

# %%
df.loc[:, 'ConvertedComp'].nlargest(10)
# Out:
# Respondent
# 22013    2000000.0
# 7139     2000000.0
# 5134     2000000.0
# 4572     2000000.0
# 4401     2000000.0
# 4901     2000000.0
# 4877     2000000.0
# 20410    2000000.0
# 20176    2000000.0
# 20388    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(10, 'ConvertedComp')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 22013       I am a developer by profession      Yes
# 7139        I am a developer by profession       No
# 5134        I am a developer by profession      Yes
# 4572        I am a developer by profession      Yes
# 4401        I am a developer by profession      Yes
# 4901        I am a developer by profession      Yes
# 4877        I am a developer by profession      Yes
# 20410       I am a developer by profession      Yes
# 20176       I am a developer by profession      Yes
# 20388       I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 22013                            Never
# 7139           Less than once per year
# 5134        Once a month or more often
# 4572                             Never
# 4401           Less than once per year
# 4901           Less than once per year
# 4877           Less than once per year
# 20410       Once a month or more often
# ...

# %%
df.loc[:, 'ConvertedComp'].nsmallest(10)
# Out:
# Respondent
# 722      0.0
# 13825    0.0
# 19340    0.0
# 16214    0.0
# 11875    0.0
# 1685     0.0
# 14883    0.0
# 1105     0.0
# 16758    0.0
# 21942    0.0
# Name: ConvertedComp, dtype: float64
