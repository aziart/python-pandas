# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.loc[:15, ['ConvertedComp']]
# Out:
#             ConvertedComp
# Respondent
# 1                     NaN
# 2                     NaN
# 3                  8820.0
# 4                 61000.0
# 5                     NaN
# 6                366420.0
# 7                     NaN
# 8                     NaN
# 9                 95179.0
# 10                13293.0
# 11                    NaN
# 12                    NaN
# 13                90000.0
# 14                57060.0
# 15                    NaN

# %%
df.loc[:, ['ConvertedComp']].median()
# Out:
# ConvertedComp    57287.0
# dtype: float64

# %%
df.median()
# Out:
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
pd.options.display.float_format = '{:,.2f}'.format
df.describe()
# Out:
#                  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs       Age
# count            14,383.00      14,359.00    16,601.00   12,812.00 20,320.00
# mean        437,696,051.14     126,919.79        42.33        5.08     30.34
# std      52,374,579,078.29     282,657.74        40.05        5.44      9.07
# min                   0.00           0.00         1.00        0.00      1.00
# 25%              20,000.00      25,980.00        40.00        2.00     24.00
# 50%              62,000.00      57,287.00        40.00        4.00     29.00
# 75%             120,000.00     100,000.00        44.00        6.00     35.00
# max   6,281,239,282,144.00   2,000,000.00     4,125.00       99.00     99.00

# %%
df.loc[:, 'ConvertedComp'].count()
# Out:
# 14359

# %%
df.loc[:, 'Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 22822    Yes
# 22823    Yes
# 22824    Yes
# 22825    Yes
# 22826    Yes
# Name: Hobbyist, Length: 22703, dtype: object

# %%
df.loc[:, 'Hobbyist'].value_counts()
# Out:
# Yes    18297
# No      4406
# Name: Hobbyist, dtype: int64

# %%
df[['SocialMedia']].head(10)
# Out:
#            SocialMedia
# Respondent
# 1              Twitter
# 2            Instagram
# 3               Reddit
# 4               Reddit
# 5             Facebook
# 6              YouTube
# 7              YouTube
# 8              YouTube
# 9              Twitter
# 10             YouTube

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      3744
# YouTube                     3489
# WhatsApp                    3461
# Facebook                    3403
# Twitter                     2950
# Instagram                   1591
# I don't use social media    1400
# LinkedIn                    1121
# Snapchat                     171
# WeChat 微信                    169
# VK ВКонта́кте                145
# Weibo 新浪微博                    16
# Youku Tudou 优酷                 9
# Hello                          7
# Name: SocialMedia, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True, )
# Out:
# Reddit                     0.17
# YouTube                    0.16
# WhatsApp                   0.16
# Facebook                   0.16
# Twitter                    0.14
# Instagram                  0.07
# I don't use social media   0.06
# LinkedIn                   0.05
# Snapchat                   0.01
# WeChat 微信                  0.01
# VK ВКонта́кте              0.01
# Weibo 新浪微博                 0.00
# Youku Tudou 优酷             0.00
# Hello                      0.00
# Name: SocialMedia, dtype: float64

# %% [markdown]
# ## PANDAS GROUPING
# ### SPLIT, APPLY FUNCTION, COMBINE RESUTS

# %%
df['Country'].head()
# Out:
# Respondent
# 1            United Kingdom
# 2    Bosnia and Herzegovina
# 3                  Thailand
# 4             United States
# 5                   Ukraine
# Name: Country, dtype: object

# %%
df['Country'].value_counts()
# Out:
# United States        5301
# India                2310
# Germany              1478
# United Kingdom       1456
# Canada                893
#                      ...
# Papua New Guinea        1
# Brunei Darussalam       1
# Gabon                   1
# Dominica                1
# Mozambique              1
# Name: Country, Length: 168, dtype: int64

# %%
df.groupby(['Country'])

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('United States').head()
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 4           I am a developer by profession       No
# 13          I am a developer by profession      Yes
# 22          I am a developer by profession      Yes
# 23          I am a developer by profession      Yes
# 26          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 4                                                       Never
# 13          Less than once a month but more than once per ...
# 22                                    Less than once per year
# 23                                    Less than once per year
# 26                                    Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 4           The quality of OSS and closed source software ...
# 13          OSS is, on average, of HIGHER quality than pro...
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt].head()
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 4           I am a developer by profession       No
# 13          I am a developer by profession      Yes
# 22          I am a developer by profession      Yes
# 23          I am a developer by profession      Yes
# 26          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 4                                                       Never
# 13          Less than once a month but more than once per ...
# 22                                    Less than once per year
# 23                                    Less than once per year
# 26                                    Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 4           The quality of OSS and closed source software ...
# 13          OSS is, on average, of HIGHER quality than pro...
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# Reddit                      1476
# Twitter                      918
# Facebook                     709
# YouTube                      612
# I don't use social media     457
# Instagram                    423
# LinkedIn                     231
# WhatsApp                     146
# Snapchat                      86
# WeChat 微信                     19
# Weibo 新浪微博                     3
# VK ВКонта́кте                  2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# WhatsApp                    765
# YouTube                     468
# LinkedIn                    239
# Facebook                    234
# Instagram                   187
# Twitter                     141
# Reddit                      129
# I don't use social media     74
# Snapchat                      4
# VK ВКонта́кте                 2
# Weibo 新浪微博                    1
# Hello                         1
# Name: SocialMedia, dtype: int64

# %%
df.groupby(['Country'])['SocialMedia'].value_counts().head(20)
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                     3
#              YouTube                      2
#              I don't use social media     1
#              Instagram                    1
# Albania      Facebook                     6
#              LinkedIn                     4
#              Twitter                      4
#              Instagram                    3
#              WhatsApp                     3
#              Reddit                       2
#              I don't use social media     1
#              Snapchat                     1
#              WeChat 微信                    1
#              YouTube                      1
# Algeria      Facebook                    11
#              YouTube                     10
#              Twitter                      4
#              I don't use social media     3
#              Instagram                    2
#              LinkedIn                     2
# Name: SocialMedia, dtype: int64

# %%
country_grp = df.groupby(['Country'])
country_grp['SocialMedia'].value_counts().head(20)
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                     3
#              YouTube                      2
#              I don't use social media     1
#              Instagram                    1
# Albania      Facebook                     6
#              LinkedIn                     4
#              Twitter                      4
#              Instagram                    3
#              WhatsApp                     3
#              Reddit                       2
#              I don't use social media     1
#              Snapchat                     1
#              WeChat 微信                    1
#              YouTube                      1
# Algeria      Facebook                    11
#              YouTube                     10
#              Twitter                      4
#              I don't use social media     3
#              Instagram                    2
#              LinkedIn                     2
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts()['India']
# Out:
# SocialMedia
# WhatsApp                    765
# YouTube                     468
# LinkedIn                    239
# Facebook                    234
# Instagram                   187
# Twitter                     141
# Reddit                      129
# I don't use social media     74
# Snapchat                      4
# VK ВКонта́кте                 2
# Hello                         1
# Weibo 新浪微博                    1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize=True)['Ukraine']
# Out:
# SocialMedia
# YouTube                    0.32
# Facebook                   0.26
# LinkedIn                   0.08
# Reddit                     0.08
# Twitter                    0.08
# I don't use social media   0.07
# Instagram                  0.07
# VK ВКонта́кте              0.01
# WhatsApp                   0.01
# WeChat 微信                  0.00
# Name: SocialMedia, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 63016.0

# %%
country_grp['ConvertedComp'].agg(['median', 'mean'])
# Out:
#                                         median      mean
# Country
# Afghanistan                           3,996.00  5,587.20
# Albania                              12,420.00 30,325.71
# Algeria                               6,612.00  7,986.86
# Andorra                                    NaN       NaN
# Angola                                7,764.00  7,764.00
# ...                                        ...       ...
# Venezuela, Bolivarian Republic of... 12,000.00 29,068.00
# Viet Nam                              7,752.00 12,816.12
# Yemen                                14,376.00 14,376.00
# Zambia                               12,607.00 12,607.00
# Zimbabwe                             19,200.00 23,040.00
#
# [168 rows x 2 columns]

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median    72,522.00
# mean     143,507.55
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'Germany'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python')
# Out:
# Respondent
# 14       False
# 36        True
# 44       False
# 66       False
# 85        True
#          ...
# 22748    False
# 22755     True
# 22771     True
# 22787    False
# 22797     True
# Name: LanguageWorkedWith, Length: 1478, dtype: object

# %%
filt = df['Country'] == 'Germany'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 650

# %%
try:
    country_grp['LanguageWorkedWith'].str.contains('Python').sum()
except AttributeError as e:
    print("AttributeError: 'SeriesGroupBy' object has no attribute 'str'")
# Out:
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python')).head()
# Out:
# Respondent
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# Name: LanguageWorkedWith, dtype: object

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              1
# Albania                                  5
# Algeria                                  5
# Andorra                                  0
# Angola                                   1
#                                         ..
# Venezuela, Bolivarian Republic of...     9
# Viet Nam                                16
# Yemen                                    1
# Zambia                                   1
# Zimbabwe                                 9
# Name: LanguageWorkedWith, Length: 168, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States        5301
# India                2310
# Germany              1478
# United Kingdom       1456
# Canada                893
#                      ...
# Papua New Guinea        1
# Brunei Darussalam       1
# Gabon                   1
# Dominica                1
# Mozambique              1
# Name: Country, Length: 168, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              1
# Albania                                  5
# Algeria                                  5
# Andorra                                  0
# Angola                                   1
#                                         ..
# Venezuela, Bolivarian Republic of...     9
# Viet Nam                                16
# Yemen                                    1
# Zambia                                   1
# Zimbabwe                                 9
# Name: LanguageWorkedWith, Length: 168, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                    Country  LanguageWorkedWith
# United States         5301                2549
# India                 2310                 802
# Germany               1478                 650
# United Kingdom        1456                 612
# Canada                 893                 421
# ...                    ...                 ...
# Papua New Guinea         1                   0
# Brunei Darussalam        1                   0
# Gabon                    1                   0
# Dominica                 1                   1
# Mozambique               1                   0
#
# [168 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)
python_df
# Out:
#                    NumRespondents  NumKnowsPython
# United States                5301            2549
# India                        2310             802
# Germany                      1478             650
# United Kingdom               1456             612
# Canada                        893             421
# ...                           ...             ...
# Papua New Guinea                1               0
# Brunei Darussalam               1               0
# Gabon                           1               0
# Dominica                        1               1
# Mozambique                      1               0
#
# [168 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                    NumRespondents  NumKnowsPython  PctKnowsPython
# United States                5301            2549           48.09
# India                        2310             802           34.72
# Germany                      1478             650           43.98
# United Kingdom               1456             612           42.03
# Canada                        893             421           47.14
# ...                           ...             ...             ...
# Papua New Guinea                1               0            0.00
# Brunei Darussalam               1               0            0.00
# Gabon                           1               0            0.00
# Dominica                        1               1          100.00
# Mozambique                      1               0            0.00
#
# [168 rows x 3 columns]

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)
python_df
# Out:
#                            NumRespondents  NumKnowsPython  PctKnowsPython
# Sierra Leone                            1               1          100.00
# Fiji                                    1               1          100.00
# Oman                                    2               2          100.00
# Congo, Republic of the...               3               3          100.00
# Guinea                                  1               1          100.00
# ...                                   ...             ...             ...
# Madagascar                              3               0            0.00
# Somalia                                 2               0            0.00
# Senegal                                 2               0            0.00
# Swaziland                               2               0            0.00
# Mozambique                              1               0            0.00
#
# [168 rows x 3 columns]

# %%
python_df.loc['Japan']
# Out:
# NumRespondents   103.00
# NumKnowsPython    48.00
# PctKnowsPython    46.60
# Name: Japan, dtype: float64
